# %%
# %matplotlib widget
import seaborn as sns
import pandas as pd
import numpy as np


df = pd.read_csv('./out.csv', dtype=float);
#df['c'] = math.sqrt(df['x']**2 + df['y']**2)
#df['pdist'] = np.sqrt(df['x']**2 + df['y']**2)
df['xp'] = df['x'].shift(1).ffill()
df['xp'][0] = 0

df['yp'] = df['y'].shift(1).ffill()
df['yp'][0] = 0

df['hue'] = np.sqrt( (df['x'] - df['xp'])**2 + (df['y'] - df['yp'])**2 )
#df['dist'] = df['pdist'].shift(1).ffill()
#df['dist'][0] = 0
#df['hue'] = df['pdist'] - df['dist']
df
# Out:
#                 x         y        xp        yp       hue
# 0        0.000000  0.000000  0.000000  0.000000  0.000000
# 1       -1.200000  1.600000  0.000000  0.000000  2.000000
# 2        0.959935 -1.538898 -1.200000  1.600000  3.810249
# 3       -0.670164  0.477716  0.959935 -1.538898  2.593059
# 4        0.118299  0.623947 -0.670164  0.477716  0.801908
# ...           ...       ...       ...       ...       ...
# 9999995  0.207024  1.472640  1.941907 -0.903935  2.942435
# 9999996 -0.427682 -0.066297  0.207024  1.472640  1.664685
# 9999997 -1.035717  1.103956 -0.427682 -0.066297  1.318787
# 9999998  1.084436 -0.556991 -1.035717  1.103956  2.693287
# 9999999 -0.581541  2.219625  1.084436 -0.556991  3.238067
#
# [10000000 rows x 5 columns]

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(11, 11))
sns.scatterplot(data=df, x='x', y='y', hue='hue', alpha=0.1, size='x', sizes=(1, 1))
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>
# /home/caleb/.conda/envs/jupyter/lib/python3.9/site-packages/ipympl/backend_nbagg.py:336: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   self.figure.savefig(buf, format='png', dpi='figure')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
